# %% [markdown]
# # Introduction to Artificial Neural Networks with Keras

# %% [markdown]
# # Setup

# %%
import sys

assert sys.version_info >= (3, 7)

# %%
from packaging import version
import sklearn

assert version.parse(sklearn.__version__) >= version.parse("1.0.1")

# %%
import tensorflow as tf

assert version.parse(tf.__version__) >= version.parse("2.8.0")

# %% [markdown]
# # Exercise solutions

# %% [markdown]
# ## 1. to 9.

# %% [markdown]
# 1. Visit the [TensorFlow Playground](https://playground.tensorflow.org/) and play around with it, as described in this exercise.
# 2. Here is a neural network based on the original artificial neurons that computes _A_ ⊕ _B_ (where ⊕ represents the exclusive OR), using the fact that _A_ ⊕ _B_ = (_A_ ∧ ¬ _B_) ∨ (¬ _A_ ∧ _B_). There are other solutions—for example, using the fact that _A_ ⊕ _B_ = (_A_ ∨ _B_) ∧ ¬(_A_ ∧ _B_), or the fact that _A_ ⊕ _B_ = (_A_ ∨ _B_) ∧ (¬ _A_ ∨ ¬ _B_), and so on.<br /><img width="70%" src="https://github.com/irnikesh/data-science/blob/main/hands-on-machine-learning/exercises/images/ann/exercise2.png?raw=1" />
# 3. A classical Perceptron will converge only if the dataset is linearly separable, and it won't be able to estimate class probabilities. In contrast, a Logistic Regression classifier will generally converge to a reasonably good solution even if the dataset is not linearly separable, and it will output class probabilities. If you change the Perceptron's activation function to the sigmoid activation function (or the softmax activation function if there are multiple neurons), and if you train it using Gradient Descent (or some other optimization algorithm minimizing the cost function, typically cross entropy), then it becomes equivalent to a Logistic Regression classifier.
# 4. The sigmoid activation function was a key ingredient in training the first MLPs because its derivative is always nonzero, so Gradient Descent can always roll down the slope. When the activation function is a step function, Gradient Descent cannot move, as there is no slope at all.
# 5. Popular activation functions include the step function, the sigmoid function, the hyperbolic tangent (tanh) function, and the Rectified Linear Unit (ReLU) function (see Figure 10-8). See Chapter 11 for other examples, such as ELU and variants of the ReLU function.
# 6. Considering the MLP described in the question, composed of one input layer with 10 passthrough neurons, followed by one hidden layer with 50 artificial neurons, and finally one output layer with 3 artificial neurons, where all artificial neurons use the ReLU activation function:
#     * The shape of the input matrix **X** is _m_ × 10, where _m_ represents the training batch size.
#     * The shape of the hidden layer's weight matrix **W**<sub>_h_</sub> is 10 × 50, and the length of its bias vector **b**<sub>_h_</sub> is 50.
#     * The shape of the output layer's weight matrix **W**<sub>_o_</sub> is 50 × 3, and the length of its bias vector **b**<sub>_o_</sub> is 3.
#     * The shape of the network's output matrix **Y** is _m_ × 3.
#     * **Y** = ReLU(ReLU(**X** **W**<sub>_h_</sub> + **b**<sub>_h_</sub>) **W**<sub>_o_</sub> + **b**<sub>_o_</sub>). Recall that the ReLU function just sets every negative number in the matrix to zero. Also note that when you are adding a bias vector to a matrix, it is added to every single row in the matrix, which is called _broadcasting_.
# 7. To classify email into spam or ham, you just need one neuron in the output layer of a neural network—for example, indicating the probability that the email is spam. You would typically use the sigmoid activation function in the output layer when estimating a probability. If instead you want to tackle MNIST, you need 10 neurons in the output layer, and you must replace the sigmoid function with the softmax activation function, which can handle multiple classes, outputting one probability per class. If you want your neural network to predict housing prices like in Chapter 2, then you need one output neuron, using no activation function at all in the output layer. Note: when the values to predict can vary by many orders of magnitude, you may want to predict the logarithm of the target value rather than the target value directly. Simply computing the exponential of the neural network's output will give you the estimated value (since exp(log _v_) = _v_).
# 8. Backpropagation is a technique used to train artificial neural networks. It first computes the gradients of the cost function with regard to every model parameter (all the weights and biases), then it performs a Gradient Descent step using these gradients. This backpropagation step is typically performed thousands or millions of times, using many training batches, until the model parameters converge to values that (hopefully) minimize the cost function. To compute the gradients, backpropagation uses reverse-mode autodiff (although it wasn't called that when backpropagation was invented, and it has been reinvented several times). Reverse-mode autodiff performs a forward pass through a computation graph, computing every node's value for the current training batch, and then it performs a reverse pass, computing all the gradients at once (see Appendix B for more details). So what's the difference? Well, backpropagation refers to the whole process of training an artificial neural network using multiple backpropagation steps, each of which computes gradients and uses them to perform a Gradient Descent step. In contrast, reverse-mode autodiff is just a technique to compute gradients efficiently, and it happens to be used by backpropagation.
# 9. Here is a list of all the hyperparameters you can tweak in a basic MLP: the number of hidden layers, the number of neurons in each hidden layer, and the activation function used in each hidden layer and in the output layer. In general, the ReLU activation function (or one of its variants; see Chapter 11) is a good default for the hidden layers. For the output layer, in general you will want the sigmoid activation function for binary classification, the softmax activation function for multiclass classification, or no activation function for regression. If the MLP overfits the training data, you can try reducing the number of hidden layers and reducing the number of neurons per hidden layer.

# %% [markdown]
# ## 10.

# %% [markdown]
# *Exercise: Train a deep MLP on the MNIST dataset (you can load it using `tf.keras.datasets.mnist.load_data()`. See if you can get over 98% accuracy by manually tuning the hyperparameters. Try searching for the optimal learning rate by using the approach presented in this chapter (i.e., by growing the learning rate exponentially, plotting the loss, and finding the point where the loss shoots up). Next, try tuning the hyperparameters using Keras Tuner with all the bells and whistles—save checkpoints, use early stopping, and plot learning curves using TensorBoard.*

# %% [markdown]
# **TODO**: update this solution to use Keras Tuner.

# %% [markdown]
# ### Repeate

# %%
(X_train_full, y_train_full), (X_test, y_test) = tf.keras.datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
X_train_full.shape
# Out:
# (60000, 28, 28)

# %%
X_train_full.dtype
# Out:
# dtype('uint8')

# %%
X_valid, X_train = X_train_full[:5000] / 255., X_train_full[5000:] / 255.
y_valid, y_train = y_train_full[:5000], y_train_full[5000:]
X_test = X_test / 255.

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=[28, 28]),
    tf.keras.layers.Dense(300, activation='relu'),
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(100, activation="relu"),
    tf.keras.layers.Dense(10, activation="softmax")
])
model.compile(loss="sparse_categorical_crossentropy", optimizer="sgd", metrics=["accuracy"])
early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)

# %%
early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)

history = model.fit(X_train, y_train, epochs=100, validation_data=(X_valid, y_valid), callbacks=[early_stopping_cb])
# Out:
# Epoch 1/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.6765 - loss: 1.1520 - val_accuracy: 0.9214 - val_loss: 0.2855
# Epoch 2/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9146 - loss: 0.2918 - val_accuracy: 0.9358 - val_loss: 0.2313
# Epoch 3/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9345 - loss: 0.2234 - val_accuracy: 0.9518 - val_loss: 0.1780
# Epoch 4/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9488 - loss: 0.1733 - val_accuracy: 0.9598 - val_loss: 0.1479
# Epoch 5/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9557 - loss: 0.1518 - val_accuracy: 0.9566 - val_loss: 0.1504
# Epoch 6/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9628 - loss: 0.1271 - val_accuracy: 0.9652 - val_loss: 0.1271
# Epoch 7/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9674 - loss: 0.1143 - val_accuracy: 0.9702 - val_loss: 0.1100
# Epoch 8/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9718 - loss: 0.1000 - val_accuracy: 0.9716 - val_loss: 0.1009
# Epoch 9/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9735 - loss: 0.0892 - val_accuracy: 0.9732 - val_loss: 0.0954
# Epoch 10/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9770 - loss: 0.0779 - val_accuracy: 0.9744 - val_loss: 0.0939
# Epoch 11/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9797 - loss: 0.0722 - val_accuracy: 0.9776 - val_loss: 0.0846
# Epoch 12/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9824 - loss: 0.0639 - val_accuracy: 0.9784 - val_loss: 0.0813
# Epoch 13/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9845 - loss: 0.0564 - val_accuracy: 0.9792 - val_loss: 0.0780
# Epoch 14/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9856 - loss: 0.0528 - val_accuracy: 0.9794 - val_loss: 0.0773
# Epoch 15/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9870 - loss: 0.0463 - val_accuracy: 0.9772 - val_loss: 0.0791
# Epoch 16/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9904 - loss: 0.0389 - val_accuracy: 0.9786 - val_loss: 0.0748
# Epoch 17/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9898 - loss: 0.0380 - val_accuracy: 0.9798 - val_loss: 0.0769
# Epoch 18/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9918 - loss: 0.0324 - val_accuracy: 0.9800 - val_loss: 0.0712
# Epoch 19/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9921 - loss: 0.0312 - val_accuracy: 0.9800 - val_loss: 0.0726
# Epoch 20/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9933 - loss: 0.0264 - val_accuracy: 0.9804 - val_loss: 0.0710
# Epoch 21/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9939 - loss: 0.0267 - val_accuracy: 0.9810 - val_loss: 0.0710
# Epoch 22/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9949 - loss: 0.0227 - val_accuracy: 0.9788 - val_loss: 0.0734
# Epoch 23/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9959 - loss: 0.0191 - val_accuracy: 0.9798 - val_loss: 0.0710
# Epoch 24/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9962 - loss: 0.0175 - val_accuracy: 0.9822 - val_loss: 0.0697
# Epoch 25/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9972 - loss: 0.0162 - val_accuracy: 0.9812 - val_loss: 0.0709
# Epoch 26/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9974 - loss: 0.0154 - val_accuracy: 0.9812 - val_loss: 0.0721
# Epoch 27/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9980 - loss: 0.0140 - val_accuracy: 0.9808 - val_loss: 0.0729
# Epoch 28/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9981 - loss: 0.0125 - val_accuracy: 0.9820 - val_loss: 0.0715
# Epoch 29/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9986 - loss: 0.0112 - val_accuracy: 0.9804 - val_loss: 0.0741
# Epoch 30/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9986 - loss: 0.0105 - val_accuracy: 0.9816 - val_loss: 0.0726
# Epoch 31/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9991 - loss: 0.0092 - val_accuracy: 0.9822 - val_loss: 0.0721
# Epoch 32/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9993 - loss: 0.0081 - val_accuracy: 0.9798 - val_loss: 0.0770
# Epoch 33/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9994 - loss: 0.0076 - val_accuracy: 0.9812 - val_loss: 0.0744
# Epoch 34/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9994 - loss: 0.0073 - val_accuracy: 0.9814 - val_loss: 0.0759

# %%
accuracy_test = model.evaluate(X_test, y_test)
print("accuracy_test: ", accuracy_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9742 - loss: 0.0846
# accuracy_test:  [0.07469078153371811, 0.9772999882698059]

# %%
learning_rate=0.1
optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer, metrics=["accuracy"])

# %%
early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)

history = model.fit(X_train, y_train, epochs=50, validation_data=(X_valid, y_valid), callbacks=[early_stopping_cb])
# Out:
# Epoch 1/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9178 - loss: 0.3749 - val_accuracy: 0.9718 - val_loss: 0.0928
# Epoch 2/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9782 - loss: 0.0677 - val_accuracy: 0.9776 - val_loss: 0.0841
# Epoch 3/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9839 - loss: 0.0477 - val_accuracy: 0.9782 - val_loss: 0.0746
# Epoch 4/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9893 - loss: 0.0326 - val_accuracy: 0.9820 - val_loss: 0.0721
# Epoch 5/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9933 - loss: 0.0203 - val_accuracy: 0.9788 - val_loss: 0.0749
# Epoch 6/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9947 - loss: 0.0172 - val_accuracy: 0.9772 - val_loss: 0.0884
# Epoch 7/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9961 - loss: 0.0125 - val_accuracy: 0.9816 - val_loss: 0.0819
# Epoch 8/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9969 - loss: 0.0112 - val_accuracy: 0.9810 - val_loss: 0.0794
# Epoch 9/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9964 - loss: 0.0098 - val_accuracy: 0.9814 - val_loss: 0.0857
# Epoch 10/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9962 - loss: 0.0101 - val_accuracy: 0.9834 - val_loss: 0.0857
# Epoch 11/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9981 - loss: 0.0057 - val_accuracy: 0.9824 - val_loss: 0.0889
# Epoch 12/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9985 - loss: 0.0048 - val_accuracy: 0.9816 - val_loss: 0.0912
# Epoch 13/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9989 - loss: 0.0037 - val_accuracy: 0.9842 - val_loss: 0.0870
# Epoch 14/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 1.0000 - loss: 5.9836e-04 - val_accuracy: 0.9846 - val_loss: 0.0863

# %%
accuracy_test = model.evaluate(X_test, y_test)
print("accuracy_test: ", accuracy_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9762 - loss: 0.0840
# accuracy_test:  [0.07081596553325653, 0.9793000221252441]

# %%
learning_rate=0.01
optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer, metrics=["accuracy"])

# %%
early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)

history = model.fit(X_train, y_train, epochs=50, validation_data=(X_valid, y_valid), callbacks=[early_stopping_cb])
# Out:
# Epoch 1/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9960 - loss: 0.0140 - val_accuracy: 0.9840 - val_loss: 0.0637
# Epoch 2/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9981 - loss: 0.0083 - val_accuracy: 0.9850 - val_loss: 0.0638
# Epoch 3/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9989 - loss: 0.0069 - val_accuracy: 0.9850 - val_loss: 0.0631
# Epoch 4/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9991 - loss: 0.0055 - val_accuracy: 0.9850 - val_loss: 0.0638
# Epoch 5/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.9993 - loss: 0.0049 - val_accuracy: 0.9848 - val_loss: 0.0638
# Epoch 6/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9992 - loss: 0.0046 - val_accuracy: 0.9848 - val_loss: 0.0640
# Epoch 7/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9995 - loss: 0.0044 - val_accuracy: 0.9846 - val_loss: 0.0651
# Epoch 8/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9995 - loss: 0.0036 - val_accuracy: 0.9844 - val_loss: 0.0654
# Epoch 9/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9996 - loss: 0.0033 - val_accuracy: 0.9850 - val_loss: 0.0661
# Epoch 10/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9995 - loss: 0.0030 - val_accuracy: 0.9844 - val_loss: 0.0661
# Epoch 11/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9997 - loss: 0.0026 - val_accuracy: 0.9850 - val_loss: 0.0664
# Epoch 12/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9997 - loss: 0.0025 - val_accuracy: 0.9852 - val_loss: 0.0669
# Epoch 13/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9998 - loss: 0.0022 - val_accuracy: 0.9846 - val_loss: 0.0671

# %%
accuracy_test = model.evaluate(X_test, y_test)
print("accuracy_test: ", accuracy_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9793 - loss: 0.0693
# accuracy_test:  [0.05858243256807327, 0.9825999736785889]

# %%
learning_rate=0.001
optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer, metrics=["accuracy"])

# %%
early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)

history = model.fit(X_train, y_train, epochs=100, validation_data=(X_valid, y_valid), callbacks=[early_stopping_cb])
# Out:
# Epoch 1/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9634 - loss: 0.1283 - val_accuracy: 0.9636 - val_loss: 0.1338
# Epoch 2/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9658 - loss: 0.1231 - val_accuracy: 0.9644 - val_loss: 0.1325
# Epoch 3/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9647 - loss: 0.1242 - val_accuracy: 0.9638 - val_loss: 0.1310
# Epoch 4/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9660 - loss: 0.1220 - val_accuracy: 0.9642 - val_loss: 0.1288
# Epoch 5/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9675 - loss: 0.1160 - val_accuracy: 0.9646 - val_loss: 0.1291
# Epoch 6/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9669 - loss: 0.1195 - val_accuracy: 0.9662 - val_loss: 0.1266
# Epoch 7/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9678 - loss: 0.1148 - val_accuracy: 0.9660 - val_loss: 0.1249
# Epoch 8/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9681 - loss: 0.1128 - val_accuracy: 0.9666 - val_loss: 0.1238
# Epoch 9/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9686 - loss: 0.1122 - val_accuracy: 0.9660 - val_loss: 0.1229
# Epoch 10/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9692 - loss: 0.1104 - val_accuracy: 0.9662 - val_loss: 0.1225
# Epoch 11/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9688 - loss: 0.1108 - val_accuracy: 0.9668 - val_loss: 0.1199
# Epoch 12/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9706 - loss: 0.1062 - val_accuracy: 0.9668 - val_loss: 0.1191
# Epoch 13/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9701 - loss: 0.1056 - val_accuracy: 0.9668 - val_loss: 0.1206
# Epoch 14/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9722 - loss: 0.1000 - val_accuracy: 0.9682 - val_loss: 0.1182
# Epoch 15/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9719 - loss: 0.1000 - val_accuracy: 0.9670 - val_loss: 0.1160
# Epoch 16/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9723 - loss: 0.0987 - val_accuracy: 0.9678 - val_loss: 0.1147
# Epoch 17/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9717 - loss: 0.1002 - val_accuracy: 0.9668 - val_loss: 0.1149
# Epoch 18/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9732 - loss: 0.0970 - val_accuracy: 0.9678 - val_loss: 0.1137
# Epoch 19/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9733 - loss: 0.0972 - val_accuracy: 0.9682 - val_loss: 0.1129
# Epoch 20/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9752 - loss: 0.0908 - val_accuracy: 0.9690 - val_loss: 0.1109
# Epoch 21/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9740 - loss: 0.0939 - val_accuracy: 0.9686 - val_loss: 0.1094
# Epoch 22/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9749 - loss: 0.0897 - val_accuracy: 0.9686 - val_loss: 0.1096
# Epoch 23/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9745 - loss: 0.0891 - val_accuracy: 0.9690 - val_loss: 0.1086
# Epoch 24/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9751 - loss: 0.0887 - val_accuracy: 0.9688 - val_loss: 0.1073
# Epoch 25/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9754 - loss: 0.0884 - val_accuracy: 0.9688 - val_loss: 0.1066
# Epoch 26/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9759 - loss: 0.0869 - val_accuracy: 0.9692 - val_loss: 0.1082
# Epoch 27/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9765 - loss: 0.0862 - val_accuracy: 0.9702 - val_loss: 0.1051
# Epoch 28/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9762 - loss: 0.0838 - val_accuracy: 0.9698 - val_loss: 0.1050
# Epoch 29/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9773 - loss: 0.0831 - val_accuracy: 0.9706 - val_loss: 0.1037
# Epoch 30/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9768 - loss: 0.0847 - val_accuracy: 0.9702 - val_loss: 0.1032
# Epoch 31/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9771 - loss: 0.0812 - val_accuracy: 0.9700 - val_loss: 0.1025
# Epoch 32/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9784 - loss: 0.0783 - val_accuracy: 0.9714 - val_loss: 0.1024
# Epoch 33/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9773 - loss: 0.0827 - val_accuracy: 0.9708 - val_loss: 0.1010
# Epoch 34/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9785 - loss: 0.0783 - val_accuracy: 0.9710 - val_loss: 0.1007
# Epoch 35/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9787 - loss: 0.0742 - val_accuracy: 0.9706 - val_loss: 0.1002
# Epoch 36/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9793 - loss: 0.0785 - val_accuracy: 0.9720 - val_loss: 0.0990
# Epoch 37/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9799 - loss: 0.0759 - val_accuracy: 0.9726 - val_loss: 0.0983
# Epoch 38/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9784 - loss: 0.0751 - val_accuracy: 0.9720 - val_loss: 0.0979
# Epoch 39/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9799 - loss: 0.0739 - val_accuracy: 0.9724 - val_loss: 0.0982
# Epoch 40/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9806 - loss: 0.0701 - val_accuracy: 0.9718 - val_loss: 0.0967
# Epoch 41/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9802 - loss: 0.0711 - val_accuracy: 0.9732 - val_loss: 0.0965
# Epoch 42/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9794 - loss: 0.0727 - val_accuracy: 0.9718 - val_loss: 0.0959
# Epoch 43/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9810 - loss: 0.0703 - val_accuracy: 0.9720 - val_loss: 0.0954
# Epoch 44/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9812 - loss: 0.0701 - val_accuracy: 0.9736 - val_loss: 0.0942
# Epoch 45/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9817 - loss: 0.0684 - val_accuracy: 0.9724 - val_loss: 0.0946
# Epoch 46/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9822 - loss: 0.0662 - val_accuracy: 0.9738 - val_loss: 0.0936
# Epoch 47/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9822 - loss: 0.0657 - val_accuracy: 0.9740 - val_loss: 0.0938
# Epoch 48/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9823 - loss: 0.0649 - val_accuracy: 0.9734 - val_loss: 0.0932
# Epoch 49/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9832 - loss: 0.0629 - val_accuracy: 0.9732 - val_loss: 0.0933
# Epoch 50/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9840 - loss: 0.0605 - val_accuracy: 0.9746 - val_loss: 0.0922
# Epoch 51/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9839 - loss: 0.0620 - val_accuracy: 0.9740 - val_loss: 0.0922
# Epoch 52/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9833 - loss: 0.0631 - val_accuracy: 0.9744 - val_loss: 0.0911
# Epoch 53/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9838 - loss: 0.0609 - val_accuracy: 0.9736 - val_loss: 0.0904
# Epoch 54/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9844 - loss: 0.0600 - val_accuracy: 0.9744 - val_loss: 0.0903
# Epoch 55/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9841 - loss: 0.0603 - val_accuracy: 0.9736 - val_loss: 0.0901
# Epoch 56/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9841 - loss: 0.0601 - val_accuracy: 0.9738 - val_loss: 0.0900
# Epoch 57/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9847 - loss: 0.0594 - val_accuracy: 0.9748 - val_loss: 0.0896
# Epoch 58/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9837 - loss: 0.0577 - val_accuracy: 0.9744 - val_loss: 0.0892
# Epoch 59/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9848 - loss: 0.0573 - val_accuracy: 0.9744 - val_loss: 0.0890
# Epoch 60/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9847 - loss: 0.0573 - val_accuracy: 0.9738 - val_loss: 0.0884
# Epoch 61/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9850 - loss: 0.0544 - val_accuracy: 0.9748 - val_loss: 0.0879
# Epoch 62/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9855 - loss: 0.0560 - val_accuracy: 0.9750 - val_loss: 0.0881
# Epoch 63/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9858 - loss: 0.0524 - val_accuracy: 0.9764 - val_loss: 0.0872
# Epoch 64/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9860 - loss: 0.0527 - val_accuracy: 0.9754 - val_loss: 0.0882
# Epoch 65/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9871 - loss: 0.0514 - val_accuracy: 0.9754 - val_loss: 0.0863
# Epoch 66/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9862 - loss: 0.0532 - val_accuracy: 0.9758 - val_loss: 0.0860
# Epoch 67/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9870 - loss: 0.0492 - val_accuracy: 0.9754 - val_loss: 0.0874
# Epoch 68/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9866 - loss: 0.0516 - val_accuracy: 0.9764 - val_loss: 0.0857
# Epoch 69/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9873 - loss: 0.0498 - val_accuracy: 0.9760 - val_loss: 0.0861
# Epoch 70/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9879 - loss: 0.0476 - val_accuracy: 0.9772 - val_loss: 0.0859
# Epoch 71/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9882 - loss: 0.0470 - val_accuracy: 0.9762 - val_loss: 0.0853
# Epoch 72/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9885 - loss: 0.0453 - val_accuracy: 0.9762 - val_loss: 0.0841
# Epoch 73/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9879 - loss: 0.0487 - val_accuracy: 0.9758 - val_loss: 0.0848
# Epoch 74/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9882 - loss: 0.0461 - val_accuracy: 0.9758 - val_loss: 0.0851
# Epoch 75/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9878 - loss: 0.0472 - val_accuracy: 0.9760 - val_loss: 0.0844
# Epoch 76/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9886 - loss: 0.0458 - val_accuracy: 0.9764 - val_loss: 0.0838
# Epoch 77/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9891 - loss: 0.0449 - val_accuracy: 0.9764 - val_loss: 0.0837
# Epoch 78/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9894 - loss: 0.0435 - val_accuracy: 0.9758 - val_loss: 0.0831
# Epoch 79/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9889 - loss: 0.0441 - val_accuracy: 0.9770 - val_loss: 0.0829
# Epoch 80/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9897 - loss: 0.0426 - val_accuracy: 0.9764 - val_loss: 0.0827
# Epoch 81/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9897 - loss: 0.0419 - val_accuracy: 0.9768 - val_loss: 0.0825
# Epoch 82/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9891 - loss: 0.0413 - val_accuracy: 0.9762 - val_loss: 0.0835
# Epoch 83/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9898 - loss: 0.0424 - val_accuracy: 0.9770 - val_loss: 0.0820
# Epoch 84/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9903 - loss: 0.0394 - val_accuracy: 0.9762 - val_loss: 0.0822
# Epoch 85/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9900 - loss: 0.0413 - val_accuracy: 0.9768 - val_loss: 0.0824
# Epoch 86/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9892 - loss: 0.0415 - val_accuracy: 0.9760 - val_loss: 0.0821
# Epoch 87/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9905 - loss: 0.0394 - val_accuracy: 0.9762 - val_loss: 0.0820
# Epoch 88/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9904 - loss: 0.0397 - val_accuracy: 0.9762 - val_loss: 0.0820
# Epoch 89/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9899 - loss: 0.0406 - val_accuracy: 0.9770 - val_loss: 0.0817
# Epoch 90/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9905 - loss: 0.0389 - val_accuracy: 0.9774 - val_loss: 0.0809
# Epoch 91/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9908 - loss: 0.0371 - val_accuracy: 0.9780 - val_loss: 0.0813
# Epoch 92/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9911 - loss: 0.0374 - val_accuracy: 0.9764 - val_loss: 0.0807
# Epoch 93/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9916 - loss: 0.0363 - val_accuracy: 0.9768 - val_loss: 0.0812
# Epoch 94/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9917 - loss: 0.0363 - val_accuracy: 0.9758 - val_loss: 0.0812
# Epoch 95/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9920 - loss: 0.0366 - val_accuracy: 0.9760 - val_loss: 0.0808
# Epoch 96/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9916 - loss: 0.0359 - val_accuracy: 0.9764 - val_loss: 0.0810
# Epoch 97/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9912 - loss: 0.0361 - val_accuracy: 0.9774 - val_loss: 0.0809
# Epoch 98/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9916 - loss: 0.0349 - val_accuracy: 0.9768 - val_loss: 0.0815
# Epoch 99/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9920 - loss: 0.0346 - val_accuracy: 0.9770 - val_loss: 0.0808
# Epoch 100/100
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9922 - loss: 0.0344 - val_accuracy: 0.9772 - val_loss: 0.0806

# %%
accuracy_test = model.evaluate(X_test, y_test)
print("accuracy_test: ", accuracy_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9697 - loss: 0.0936
# accuracy_test:  [0.0782490149140358, 0.9754999876022339]

# %%
tf.random.set_seed(42)

# %%
# pip install keras_tuner

# %%
import keras_tuner as kt

def build_model(hp: kt.HyperParameters):
  n_hidden = hp.Int("n_hidden", min_value=0, max_value=8, default=2)
  n_neurons = hp.Int("n_neurons", min_value=16, max_value=256)
  learning_rate = hp.Float("learning_rate", min_value=1e-4, max_value=1e-2,
                             sampling="log")
  optimizer = hp.Choice("optimizer", values=["sgd", "adam"])
  if optimizer == "sgd":
      optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate)
  else:
      optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)

  model = tf.keras.Sequential()
  model.add(tf.keras.layers.Flatten())
  for _ in range(n_hidden):
      model.add(tf.keras.layers.Dense(n_neurons, activation="relu"))
  model.add(tf.keras.layers.Dense(10, activation="softmax"))
  model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer,
                  metrics=["accuracy"])
  return model

# %%
class MyClassificationHyperModel(kt.HyperModel):
    def build(self, hp):
        return build_model(hp)

    def fit(self, hp, model, X, y, **kwargs):
        if hp.Boolean("normalize"):
            norm_layer = tf.keras.layers.Normalization()
            X = norm_layer(X)
        return model.fit(X, y, **kwargs)

# %%
hyperband_tuner = kt.Hyperband(
    MyClassificationHyperModel(), objective="val_accuracy", seed=42,
    max_epochs=10, factor=3, hyperband_iterations=2,
    overwrite=True, directory="mnist", project_name="hyperband")

# %%
# TODO: save checkpoints

# %%
from pathlib import Path

root_logdir = Path(hyperband_tuner.project_dir) / "tensorboard"
tensorboard_cb = tf.keras.callbacks.TensorBoard(root_logdir)
early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=2)
hyperband_tuner.search(X_train, y_train, epochs=10,
                       validation_data=(X_valid, y_valid),
                       callbacks=[early_stopping_cb, tensorboard_cb])
# Out:
# Trial 60 Complete [00h 01m 01s]
# val_accuracy: 0.9395999908447266
#
# Best val_accuracy So Far: 0.979200005531311
# Total elapsed time: 00h 32m 30s

# %%
pip install -q -U tensorboard-plugin-profile

# %%
# %load_ext tensorboard
# %tensorboard --logdir={root_logdir}

# %%
hyperband_tuner.get_best_hyperparameters(num_trials=1)[0].values
# Out:
# {'n_hidden': 2,
#  'n_neurons': 251,
#  'learning_rate': 0.001715074355925934,
#  'optimizer': 'adam',
#  'normalize': False,
#  'tuner/epochs': 10,
#  'tuner/initial_epoch': 4,
#  'tuner/bracket': 2,
#  'tuner/round': 2,
#  'tuner/trial_id': '0012'}

# %% [markdown]
# ### Original

# %% [markdown]
# Let's load the dataset:

# %%
(X_train_full, y_train_full), (X_test, y_test) = tf.keras.datasets.mnist.load_data()

# %% [markdown]
# Just like for the Fashion MNIST dataset, the MNIST training set contains 60,000 grayscale images, each 28x28 pixels:

# %%
X_train_full.shape
# Out:
# (60000, 28, 28)

# %% [markdown]
# Each pixel intensity is also represented as a byte (0 to 255):

# %%
X_train_full.dtype
# Out:
# dtype('uint8')

# %% [markdown]
# Let's split the full training set into a validation set and a (smaller) training set. We also scale the pixel intensities down to the 0-1 range and convert them to floats, by dividing by 255, just like we did for Fashion MNIST:

# %%
X_valid, X_train = X_train_full[:5000] / 255., X_train_full[5000:] / 255.
y_valid, y_train = y_train_full[:5000], y_train_full[5000:]
X_test = X_test / 255.

# %% [markdown]
# Let's plot an image using Matplotlib's `imshow()` function, with a `'binary'`
#  color map:

# %%
plt.imshow(X_train[0], cmap="binary")
plt.axis('off')
plt.show()

# %% [markdown]
# The labels are the class IDs (represented as uint8), from 0 to 9. Conveniently, the class IDs correspond to the digits represented in the images, so we don't need a `class_names` array:

# %%
y_train
# Out:
# array([7, 3, 4, ..., 5, 6, 8], dtype=uint8)

# %% [markdown]
# The validation set contains 5,000 images, and the test set contains 10,000 images:

# %%
X_valid.shape
# Out:
# (5000, 28, 28)

# %%
X_test.shape
# Out:
# (10000, 28, 28)

# %% [markdown]
# Let's take a look at a sample of the images in the dataset:

# %%
n_rows = 4
n_cols = 10
plt.figure(figsize=(n_cols * 1.2, n_rows * 1.2))
for row in range(n_rows):
    for col in range(n_cols):
        index = n_cols * row + col
        plt.subplot(n_rows, n_cols, index + 1)
        plt.imshow(X_train[index], cmap="binary", interpolation="nearest")
        plt.axis('off')
        plt.title(y_train[index])
plt.subplots_adjust(wspace=0.2, hspace=0.5)
plt.show()

# %% [markdown]
# Let's build a simple dense network and find the optimal learning rate. We will need a callback to grow the learning rate at each iteration. It will also record the learning rate and the loss at each iteration:

# %%
K = tf.keras.backend

class ExponentialLearningRate(tf.keras.callbacks.Callback):
    def __init__(self, factor):
        self.factor = factor
        self.rates = []
        self.losses = []

    def on_batch_end(self, batch, logs=None):
        lr = self.model.optimizer.learning_rate.numpy() * self.factor
        self.model.optimizer.learning_rate = lr
        self.rates.append(lr)
        self.losses.append(logs["loss"])

# %%
tf.keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=[28, 28]),
    tf.keras.layers.Dense(300, activation="relu"),
    tf.keras.layers.Dense(100, activation="relu"),
    tf.keras.layers.Dense(10, activation="softmax")
])

# %% [markdown]
# We will start with a small learning rate of 1e-3, and grow it by 0.5% at each iteration:

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=1e-3)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer,
              metrics=["accuracy"])
expon_lr = ExponentialLearningRate(factor=1.005)

# %% [markdown]
# Now let's train the model for just 1 epoch:

# %%
history = model.fit(X_train, y_train, epochs=1,
                    validation_data=(X_valid, y_valid),
                    callbacks=[expon_lr])
# Out:
# 1719/1719 [==============================] - 3s 2ms/step - loss: nan - accuracy: 0.5843 - val_loss: nan - val_accuracy: 0.0958

# %% [markdown]
# We can now plot the loss as a functionof the learning rate:

# %%
plt.plot(expon_lr.rates, expon_lr.losses)
plt.gca().set_xscale('log')
plt.hlines(min(expon_lr.losses), min(expon_lr.rates), max(expon_lr.rates))
plt.axis([min(expon_lr.rates), max(expon_lr.rates), 0, expon_lr.losses[0]])
plt.grid()
plt.xlabel("Learning rate")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')

# %% [markdown]
# The loss starts shooting back up violently when the learning rate goes over 6e-1, so let's try using half of that, at 3e-1:

# %%
tf.keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=[28, 28]),
    tf.keras.layers.Dense(300, activation="relu"),
    tf.keras.layers.Dense(100, activation="relu"),
    tf.keras.layers.Dense(10, activation="softmax")
])

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=3e-1)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer,
              metrics=["accuracy"])

# %%
run_index = 1 # increment this at every run
run_logdir = Path() / "my_mnist_logs" / "run_{:03d}".format(run_index)
run_logdir
# Out:
# PosixPath('my_mnist_logs/run_001')

# %%
early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=20)
checkpoint_cb = tf.keras.callbacks.ModelCheckpoint("my_mnist_model.keras", save_best_only=True)
tensorboard_cb = tf.keras.callbacks.TensorBoard(run_logdir)

history = model.fit(X_train, y_train, epochs=100,
                    validation_data=(X_valid, y_valid),
                    callbacks=[checkpoint_cb, early_stopping_cb, tensorboard_cb])
# Out:
# Epoch 1/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2363 - accuracy: 0.9264 - val_loss: 0.0972 - val_accuracy: 0.9720
# Epoch 2/100
# 1719/1719 [==============================] - 2s 997us/step - loss: 0.0948 - accuracy: 0.9702 - val_loss: 0.1035 - val_accuracy: 0.9706
# Epoch 3/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.0667 - accuracy: 0.9792 - val_loss: 0.0783 - val_accuracy: 0.9770
# Epoch 4/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.0463 - accuracy: 0.9848 - val_loss: 0.0827 - val_accuracy: 0.9766
# Epoch 5/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.0359 - accuracy: 0.9881 - val_loss: 0.0698 - val_accuracy: 0.9826
# Epoch 6/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.0297 - accuracy: 0.9908 - val_loss: 0.1048 - val_accuracy: 0.9758
# Epoch 7/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.0245 - accuracy: 0.9917 - val_loss: 0.0932 - val_accuracy: 0.9794
# Epoch 8/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.0239 - accuracy: 0.9922 - val_loss: 0.0816 - val_accuracy: 0.9798
# Epoch 9/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.0154 - accuracy: 0.9952 - val_loss: 0.0775 - val_accuracy: 0.9838
# Epoch 10/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.0126 - accuracy: 0.9960 - val_loss: 0.0805 - val_accuracy: 0.9812
# Epoch 11/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.0111 - accuracy: 0.9964 - val_loss: 0.0962 - val_accuracy: 0.9804
# Epoch 12/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.0118 - accuracy: 0.9963 - val_loss: 0.1044 - val_accuracy: 0.9774
# Epoch 13/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.0114 - accuracy: 0.9961 - val_loss: 0.1055 - val_accuracy: 0.9802
# Epoch 14/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.0150 - accuracy: 0.9948 - val_loss: 0.0993 - val_accuracy: 0.9826
# Epoch 15/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.0054 - accuracy: 0.9981 - val_loss: 0.0955 - val_accuracy: 0.9822
# Epoch 16/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.0046 - accuracy: 0.9984 - val_loss: 0.0982 - val_accuracy: 0.9822
# Epoch 17/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.0055 - accuracy: 0.9983 - val_loss: 0.0908 - val_accuracy: 0.9844
# Epoch 18/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.0070 - accuracy: 0.9978 - val_loss: 0.0883 - val_accuracy: 0.9840
# Epoch 19/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.0025 - accuracy: 0.9992 - val_loss: 0.0978 - val_accuracy: 0.9838
# Epoch 20/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.0058 - accuracy: 0.9983 - val_loss: 0.1011 - val_accuracy: 0.9830
# Epoch 21/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.0039 - accuracy: 0.9989 - val_loss: 0.0991 - val_accuracy: 0.9840
# Epoch 22/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 9.2480e-04 - accuracy: 0.9998 - val_loss: 0.0963 - val_accuracy: 0.9840
# Epoch 23/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 1.2642e-04 - accuracy: 1.0000 - val_loss: 0.0970 - val_accuracy: 0.9846
# Epoch 24/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 6.9068e-05 - accuracy: 1.0000 - val_loss: 0.0970 - val_accuracy: 0.9854
# Epoch 25/100
# 1719/1719 [==============================] - 2s 1ms/step - loss: 5.1481e-05 - accuracy: 1.0000 - val_loss: 0.0977 - val_accuracy: 0.9850

# %%
model = tf.keras.models.load_model("my_mnist_model.keras") # rollback to best model
model.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 0s 908us/step - loss: 0.0708 - accuracy: 0.9799
# [0.07079131156206131, 0.9799000024795532]

# %% [markdown]
# We got over 98% accuracy. Finally, let's look at the learning curves using TensorBoard:

# %%
# %tensorboard --logdir=./my_mnist_logs
# Out:
#       <iframe id="tensorboard-frame-9f95f24bb0151492" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-9f95f24bb0151492");
#           const url = new URL("/", window.location);
#           const port = 6008;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
